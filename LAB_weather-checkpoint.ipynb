# %%
#python analysis lab 




# The commands that we used in this project :

# * head() - It shows the first N rows in the data (by default, N=5).
# * shape - It shows the total no. of rows and no. of columns of the dataframe
# * index - This attribute provides the index of the dataframe
# * columns - It shows the name of each column
# * dtypes - It shows the data-type of each column
# * unique() - In a column, it shows all the unique values. It can be applied on a single column only, not on the whole dataframe.
# * nunique() - It shows the total no. of unique values in each column. It can be applied on a single column as well as on the whole dataframe.
# * count - It shows the total no. of non-null values in each column. It can be applied on a single column as well as on the whole dataframe.
# * value_counts - In a column, it shows all the unique values with their count. It can be applied on a single column only.
# * info() - Provides basic information about the dataframe.


import pandas as pd

# import csv

#this function is used to pull data from any csv file and make a list of data for it to be ready to be processed using python queries
# def load_data(filename):
#     mylist = []
#     with open(filename) as numbers:
#         numbers_data = csv.reader(numbers, delimiter=',')
#         #next(numbers_data) #this will skip the header in the csv
#         for row in numbers_data:
#             mylist.append(row) #this will pull data from the csv file and make a list of list
#             #mylist.append(row[index_number]) this will pull data specific to the given index number
#         return mylist

# newlist = load_data('weather.csv');

# newlist = np.array(newlist)

# for row in newlist:
#     print(row)
    
#uniq = np.unique(newlist) #syntax to get unique values
# for row[4] in newlist:
#     unique.append(np.unique(row));

# for row in unique:
#     print(row)
newlist = pd.read_csv(r"weather.csv") #if the csv is in same folder then we just need to provide the name otherwise we need to provide the full address   

# print(newlist)
# newlist.head(5)
    
#Q. 1)  Find all the unique 'Wind Speed' values in the data.
newlist['Wind Speed_km/h'].unique() #syntax is variablename['columnname'].unique();

#Q. 2) Find the number of times when the 'Weather is exactly Clear'.
newlist[newlist['Weather']=='Clear']

#Q. 3) Find the number of times when the 'Wind Speed was exactly 4 km/h'.

newlist[newlist['Wind Speed_km/h']==4].count() #this is one method

newlist[newlist['Wind Speed_km/h']==4].value_counts("Wind Speed_km/h") #this is another method

newlist['Wind Speed_km/h'].where(newlist['Wind Speed_km/h']==4).count() #this is another method

#Q. 4) Find out all the Null Values in the data.
newlist.isnull().sum()

#Q. 5) Rename the column name 'Weather' of the dataframe to 'Weather Condition'
#newlist.rename(columns={'Weather':'Weather Condition'}) #if we write this only then the next time when we print the dataset it will again revert back to 'Weather'
#so instead we have to write 

newlist.rename(columns={'Weather':'Weather Condition'}, inplace=True) #using this the Weather condition will not revert back to the Weather

print(newlist)
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...
